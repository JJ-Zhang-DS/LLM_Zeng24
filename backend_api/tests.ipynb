# %% [markdown]
# # lesson 2
#
# sample codes.
#
# Ref
#
# https://github.com/openai/openai-python

# %%
import json
from openai import OpenAI
from dotenv import load_dotenv
import os

# Load environment variables from .env file
load_dotenv()

# Get the API key
openai_api_key = os.getenv('OPENAI_API_KEY')

# %%
# Initialize the OpenAI client with the API key
client = OpenAI()

# %%
model_list = client.models.list()

# %%
print(model_list)
# Out:
# SyncPage[Model](data=[Model(id='gpt-4o-audio-preview-2024-10-01', created=1727389042, object='model', owned_by='system'), Model(id='gpt-4o-mini-audio-preview', created=1734387424, object='model', owned_by='system'), Model(id='gpt-4o-realtime-preview', created=1727659998, object='model', owned_by='system'), Model(id='gpt-4o-realtime-preview-2024-10-01', created=1727131766, object='model', owned_by='system'), Model(id='gpt-4o-mini-audio-preview-2024-12-17', created=1734115920, object='model', owned_by='system'), Model(id='gpt-4o-mini-realtime-preview', created=1734387380, object='model', owned_by='system'), Model(id='dall-e-2', created=1698798177, object='model', owned_by='system'), Model(id='gpt-4-1106-preview', created=1698957206, object='model', owned_by='system'), Model(id='gpt-4o-realtime-preview-2024-12-17', created=1733945430, object='model', owned_by='system'), Model(id='gpt-3.5-turbo', created=1677610602, object='model', owned_by='openai'), Model(id='gpt-3.5-turbo-0125', created=1706048358, object='model', owned_by='system'), Model(id='gpt-3.5-turbo-instruct', created=1692901427, object='model', owned_by='system'), Model(id='babbage-002', created=1692634615, object='model', owned_by='system'), Model(id='whisper-1', created=1677532384, object='model', owned_by='openai-internal'), Model(id='dall-e-3', created=1698785189, object='model', owned_by='system'), Model(id='text-embedding-3-small', created=1705948997, object='model', owned_by='system'), Model(id='gpt-3.5-turbo-16k', created=1683758102, object='model', owned_by='openai-internal'), Model(id='omni-moderation-latest', created=1731689265, object='model', owned_by='system'), Model(id='o1-preview-2024-09-12', created=1725648865, object='model', owned_by='system'), Model(id='omni-moderation-2024-09-26', created=1732734466, object='model', owned_by='system'), Model(id='tts-1-hd-1106', created=1699053533, object='model', owned_by='system'), Model(id='o1-preview', created=1725648897, object='model', owned_by='system'), Model(id='gpt-4', created=1687882411, object='model', owned_by='openai'), Model(id='gpt-4-0613', created=1686588896, object='model', owned_by='openai'), Model(id='chatgpt-4o-latest', created=1723515131, object='model', owned_by='system'), Model(id='gpt-4-0125-preview', created=1706037612, object='model', owned_by='system'), Model(id='tts-1-hd', created=1699046015, object='model', owned_by='system'), Model(id='davinci-002', created=1692634301, object='model', owned_by='system'), Model(id='text-embedding-ada-002', created=1671217299, object='model', owned_by='openai-internal'), Model(id='gpt-3.5-turbo-1106', created=1698959748, object='model', owned_by='system'), Model(id='gpt-4o-audio-preview', created=1727460443, object='model', owned_by='system'), Model(id='gpt-4-turbo-2024-04-09', created=1712601677, object='model', owned_by='system'), Model(id='gpt-4-turbo', created=1712361441, object='model', owned_by='system'), Model(id='tts-1', created=1681940951, object='model', owned_by='openai-internal'), Model(id='tts-1-1106', created=1699053241, object='model', owned_by='system'), Model(id='gpt-3.5-turbo-instruct-0914', created=1694122472, object='model', owned_by='system'), Model(id='text-embedding-3-large', created=1705953180, object='model', owned_by='system'), Model(id='gpt-4-turbo-preview', created=1706037777, object='model', owned_by='system'), Model(id='gpt-4o-mini-realtime-preview-2024-12-17', created=1734112601, object='model', owned_by='system'), Model(id='gpt-4o', created=1715367049, object='model', owned_by='system'), Model(id='gpt-4o-2024-05-13', created=1715368132, object='model', owned_by='system'), Model(id='gpt-4o-2024-08-06', created=1722814719, object='model', owned_by='system'), Model(id='gpt-4o-2024-11-20', created=1731975040, object='model', owned_by='system'), Model(id='o1-mini', created=1725649008, object='model', owned_by='system'), Model(id='o1-mini-2024-09-12', created=1725648979, object='model', owned_by='system'), Model(id='gpt-4o-audio ...

# %%
model_list.to_dict()
# Out:
# {'data': [{'id': 'gpt-4o-audio-preview-2024-10-01',
#    'created': 1727389042,
#    'object': 'model',
#    'owned_by': 'system'},
#   {'id': 'gpt-4o-mini-audio-preview',
#    'created': 1734387424,
#    'object': 'model',
#    'owned_by': 'system'},
#   {'id': 'gpt-4o-realtime-preview',
#    'created': 1727659998,
#    'object': 'model',
#    'owned_by': 'system'},
#   {'id': 'gpt-4o-realtime-preview-2024-10-01',
#    'created': 1727131766,
#    'object': 'model',
#    'owned_by': 'system'},
#   {'id': 'gpt-4o-mini-audio-preview-2024-12-17',
#    'created': 1734115920,
#    'object': 'model',
#    'owned_by': 'system'},
#   {'id': 'gpt-4o-mini-realtime-preview',
#    'created': 1734387380,
#    'object': 'model',
#    'owned_by': 'system'},
#   {'id': 'dall-e-2',
#    'created': 1698798177,
#    'object': 'model',
#    'owned_by': 'system'},
#   {'id': 'gpt-4-1106-preview',
#    'created': 1698957206,
#    'object': 'model',
#    'owned_by': 'system'},
#   {'id': 'gpt-4o-realtime-preview-2024-12-17',
#    'created': 1733945430,
#    'object': 'model',
#    'owned_by': 'system'},
#   {'id': 'gpt-3.5-turbo',
#    'created': 1677610602,
#    'object': 'model',
#    'owned_by': 'openai'},
#   {'id': 'gpt-3.5-turbo-0125',
#    'created': 1706048358,
#    'object': 'model',
#    'owned_by': 'system'},
#   {'id': 'gpt-3.5-turbo-instruct',
#    'created': 1692901427,
#    'object': 'model',
#    'owned_by': 'system'},
#   {'id': 'babbage-002',
#    'created': 1692634615,
#    'object': 'model',
#    'owned_by': 'system'},
#   {'id': 'whisper-1',
#    'created': 1677532384,
#    'object': 'model',
#    'owned_by': 'openai-internal'},
#   {'id': 'dall-e-3',
#    'created': 1698785189,
#    'object': 'model',
#    'owned_by': 'system'},
#   {'id': 'text-embedding-3-small',
#    'created': 1705948997,
#    'object': 'model',
#    'owned_by': 'system'},
#   {'id': 'gpt-3.5-turbo-16k',
#    'created': 1683758102,
#    'object': 'model',
#    'owned_by': 'openai-internal'},
#   {'id': 'omni-moderation-latest',
#    'created': 1731689265,
#    'object': 'model',
#    'owned_by': 'system'},
#   {'id': 'o1-preview-2024-09-12',
#    'created': 1725648865,
#    'object': 'model',
#    'owned_by': 'system'},
#   {'id': 'omni-moderation-2024-09-26',
#    'created': 1732734466,
#    'object': 'model',
#    'owned_by': 'system'},
#   {'id': 'tts-1-hd-1106',
#    'created': 1699053533,
#    'object': 'model',
#    'owned_by': 'system'},
#   {'id': 'o1-preview',
#    'created': 1725648897,
#    'object': 'model',
#    'owned_by': 'system'},
#   {'id': 'gpt-4',
#    'created': 1687882411,
#    'object': 'model',
#    'owned_by': 'openai'},
#   {'id': 'gpt-4-0613',
#    'created': 1686588896,
#    'object': 'model',
#    'owned_by': 'openai'},
#   {'id': 'chatgpt-4o-latest',
#    'created': 1723515131,
#    'object': 'model',
#    'owned_by': 'system'},
#   {'id': 'gpt-4-0125-preview',
#    'created': 1706037612,
#    'object': 'model',
#    'owned_by': 'system'},
#   {'id': 'tts-1-hd',
#    'created': 1699046015,
#    'object': 'model',
#    'owned_by': 'system'},
#   {'id': 'davinci-002',
#    'created': 1692634301,
#    'object': 'model',
#    'owned_by': 'system'},
#   {'id': 'text-embedding-ada-002',
#    'created': 1671217299,
#    'object': 'model',
#    'owned_by': 'openai-internal'},
#   {'id': 'gpt-3.5-turbo-1106',
#    'created': 1698959748,
#    'object': 'model',
#    'owned_by': 'system'},
#   {'id': 'gpt-4o-audio-preview',
#    'created': 1727460443,
#    'object': 'model',
#    'owned_by': 'system'},
#   {'id': 'gpt-4-turbo-2024-04-09',
#    'created': 1712601677,
#    'object': 'model',
#    'owned_by': 'system'},
#   {'id': 'gpt-4-turbo',
#    'created': 1712361441,
#    'object': 'model',
#    'owned_by': 'system'},
#   {'id': 'tts-1',
#    'created': 1681940951,
#    'object': 'model',
#    'owned_by': 'openai-internal'},
#   {'id': 'tts-1-1106',
#    'created': 1699053241,
#    'object': 'model',
#    'owned_by': 'system'},
#   {'id': 'gpt-3.5-turbo-instruct-0914',
#    'created': 1694122472,
#    'object': 'model',
#    'owned_by': 'system'},
#   {'id': 'text-embedding-3-large',
#    'created': 1705953180,
#    'object': 'model',
#    'owned_by': 'system'},
#   {'id': 'gpt-4-turbo-preview',
#    'created': 1706037777,
#    'object': 'model',
#    'owned_by': 'system'},
#   {'id': 'gpt-4o-mini-realtime-preview-2024-12-17',
#    'created': 1734112601,
#    'object': 'model',
#    'owned_by': 'system'},
#   {'id': 'gpt-4o',
#    'created': 1715367049,
#    'object': 'model',
#    'owned_by': 'system'},
#   {'id': 'gpt-4o-2024-05-13',
#    'created': 1715368132,
#    'object': 'model',
#    'owned_by': 'system'},
#   {'id': 'gpt-4o-2024-08-06',
#    'created': 1722814719,
#    'object': 'model',
#    'owned_by': 'system'},
#   {'id': 'gpt-4o-2024-11-20',
#    'created': 1731975040,
#    'object': 'model',
#    'owned_by': 'system'},
#   {'id': 'o1-mini',
#    'created': 1725649008,
#    'object': 'model',
#    'owned_by': 'system'},
#   {'id': 'o1-mini-2024-09-12',
#    'created': 1725648979,
#    'object': 'model',
#    'owned_by': 'system'},
#   {'id': 'gpt-4o-audio-preview-2024-12-17',
#    'created': 1734034239,
#    'object': 'model',
#    'owned_by': 'system'},
#   {'id': 'gpt-4o-mini-2024-07-18',
#    'created': 1721172717,
#    'object': 'model',
#    'owned_by': 'system'},
#   {'id': 'gpt-4o-mini',
#    'created': 1721172741,
#    'object': 'model',
#    'owned_by': 'system'}],
#  'object': 'list'}

# %%
print(json.dumps(model_list.to_dict(), indent=2))
# Out:
# {
#   "data": [
#     {
#       "id": "gpt-4o-audio-preview-2024-10-01",
#       "created": 1727389042,
#       "object": "model",
#       "owned_by": "system"
#     },
#     {
#       "id": "gpt-4o-mini-audio-preview",
#       "created": 1734387424,
#       "object": "model",
#       "owned_by": "system"
#     },
#     {
#       "id": "gpt-4o-realtime-preview",
#       "created": 1727659998,
#       "object": "model",
#       "owned_by": "system"
#     },
#     {
#       "id": "gpt-4o-realtime-preview-2024-10-01",
#       "created": 1727131766,
#       "object": "model",
#       "owned_by": "system"
#     },
#     {
#       "id": "gpt-4o-mini-audio-preview-2024-12-17",
#       "created": 1734115920,
#       "object": "model",
#       "owned_by": "system"
#     },
#     {
#       "id": "gpt-4o-mini-realtime-preview",
#       "created": 1734387380,
#       "object": "model",
#       "owned_by": "system"
#     },
#     {
#       "id": "dall-e-2",
#       "created": 1698798177,
#       "object": "model",
#       "owned_by": "system"
#     },
#     {
#       "id": "gpt-4-1106-preview",
#       "created": 1698957206,
#       "object": "model",
#       "owned_by": "system"
#     },
#     {
#       "id": "gpt-4o-realtime-preview-2024-12-17",
#       "created": 1733945430,
#       "object": "model",
#       "owned_by": "system"
#     },
#     {
#       "id": "gpt-3.5-turbo",
#       "created": 1677610602,
#       "object": "model",
#       "owned_by": "openai"
#     },
#     {
#       "id": "gpt-3.5-turbo-0125",
#       "created": 1706048358,
#       "object": "model",
#       "owned_by": "system"
#     },
#     {
#       "id": "gpt-3.5-turbo-instruct",
#       "created": 1692901427,
#       "object": "model",
#       "owned_by": "system"
#     },
#     {
#       "id": "babbage-002",
#       "created": 1692634615,
#       "object": "model",
#       "owned_by": "system"
#     },
#     {
#       "id": "whisper-1",
#       "created": 1677532384,
#       "object": "model",
#       "owned_by": "openai-internal"
#     },
#     {
#       "id": "dall-e-3",
#       "created": 1698785189,
#       "object": "model",
#       "owned_by": "system"
#     },
#     {
#       "id": "text-embedding-3-small",
#       "created": 1705948997,
#       "object": "model",
#       "owned_by": "system"
#     },
#     {
#       "id": "gpt-3.5-turbo-16k",
#       "created": 1683758102,
#       "object": "model",
#       "owned_by": "openai-internal"
#     },
#     {
#       "id": "omni-moderation-latest",
#       "created": 1731689265,
#       "object": "model",
#       "owned_by": "system"
#     },
#     {
#       "id": "o1-preview-2024-09-12",
#       "created": 1725648865,
#       "object": "model",
#       "owned_by": "system"
#     },
#     {
#       "id": "omni-moderation-2024-09-26",
#       "created": 1732734466,
#       "object": "model",
#       "owned_by": "system"
#     },
#     {
#       "id": "tts-1-hd-1106",
#       "created": 1699053533,
#       "object": "model",
#       "owned_by": "system"
#     },
#     {
#       "id": "o1-preview",
#       "created": 1725648897,
#       "object": "model",
#       "owned_by": "system"
#     },
#     {
#       "id": "gpt-4",
#       "created": 1687882411,
#       "object": "model",
#       "owned_by": "openai"
#     },
#     {
#       "id": "gpt-4-0613",
#       "created": 1686588896,
#       "object": "model",
#       "owned_by": "openai"
#     },
#     {
#       "id": "chatgpt-4o-latest",
#       "created": 1723515131,
#       "object": "model",
#       "owned_by": "system"
#     },
#     {
#       "id": "gpt-4-0125-preview",
#       "created": 1706037612,
#       "object": "model",
#       "owned_by": "system"
#     },
#     {
#       "id": "tts-1-hd",
#       "created": 1699046015,
#       "object": "model",
#       "owned_by": "system"
#     },
#     {
#       "id": "davinci-002",
#       "created": 1692634301,
#       "object": "model",
#       "owned_by": "system"
#     },
#     {
#       "id": "text-embedding-ada-002",
#       "created": 1671217299,
#       "object": "model",
#       "owned_by": "openai-internal"
#     },
#     {
#       "id": "gpt-3.5-turbo-1106",
#       "created": 1698959748,
#       "object": "model",
#       "owned_by": "system"
#     },
#     {
#       "id": "gpt-4o-audio-preview",
#       "created": 1727460443,
#       "object": "model",
#       "owned_by": "system"
#     },
#     {
#       "id": "gpt-4-turbo-2024-04-09",
#       "created": 1712601677,
#       "object": "model",
#       "owned_by": "system"
#     },
#     {
#       "id": "gpt-4-turbo",
#       "created": 1712361441,
#       "object": "model",
#       "owned_by": "system"
#     },
#     {
#       "id": "tts-1",
#       "created": 1681940951,
#       "object": "model",
#       "owned_by": "openai-internal"
#     },
#     {
#       "id": "tts-1-1106",
#       "created": 1699053241,
#       "object": "model",
#       "owned_by": "system"
#     },
#     {
#       "id": "gpt-3.5-turbo-instruct-0914",
#       "created": 1694122472,
#       "object": "model",
#       "owned_by": "system"
#     },
#     {
#       "id": "text-embedding-3-large",
#       "created": 1705953180,
#       "object": "model",
#       "owned_by": "system"
#     },
#     {
#       "id": "gpt-4-turbo-preview",
#       "created": 1706037777,
#       "object": "model",
#       "owned_by": "system"
#     },
#     {
#       "id": "gpt-4o-mini-realtime-preview-2024-12-17",
#       "created": 1734112601,
#       "object": "model",
#       "owned_by": "system"
#     },
#     {
#       "id": "gpt-4o",
#       "created": 1715367049,
#       "object": "model",
#       "owned_by": "system"
#     },
#     {
#       "id": "gpt-4o-2024-05-13",
#       "created": 1715368132,
#       "object": "model",
#       "owned_by": "system"
#     },
#     {
#       "id": "gpt-4o-2024-08-06",
#       "created": 1722814719,
#       "object": "model",
#       "owned_by": "system"
#     },
#     {
#       "id": "gpt-4o-2024-11-20",
#       "created": 1731975040,
#       "object": "model",
#       "owned_by": "system"
#     },
#     {
#       "id": "o1-mini",
#       "created": 1725649008,
#       "object": "model",
#       "owned_by": "system"
#     },
#     {
#       "id": "o1-mini-2024-09-12",
#       "created": 1725648979,
#       "object": "model",
#       "owned_by": "system"
#     },
#     {
#       "id": "gpt-4o-audio-preview-2024-12-17",
#       "created": 1734034239,
#       "object": "model",
#       "owned_by": "system"
#     },
#     {
#       "id": "gpt-4o-mini-2024-07-18",
#       "created": 1721172717,
#       "object": "model",
#       "owned_by": "system"
#     },
#     {
#       "id": "gpt-4o-mini",
#       "created": 1721172741,
#       "object": "model",
#       "owned_by": "system"
#     }
#   ],
#   "object": "list"
# }

# %%
import os
from openai import OpenAI

client = OpenAI(
    api_key=os.environ.get("OPENAI_API_KEY"),  # This is the default and can be omitted
)

result = chat_completion = client.chat.completions.create(
    messages=[
        {
            "role": "user",
            "content": "Say this is a test",
        }
    ],
    model="gpt-4o",
)

# %%
print(result)
# Out:
# ChatCompletion(id='chatcmpl-AmtBOvvjX6KDgvVxQiQGTkSHoJTXX', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='This is a test. How can I assist you further?', role='assistant', function_call=None, tool_calls=None, refusal=None))], created=1736215230, model='gpt-4o-2024-08-06', object='chat.completion', system_fingerprint='fp_5f20662549', usage=CompletionUsage(completion_tokens=13, prompt_tokens=12, total_tokens=25, prompt_tokens_details={'cached_tokens': 0, 'audio_tokens': 0}, completion_tokens_details={'reasoning_tokens': 0, 'audio_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}))

# %%
print(result.choices[0])
# Out:
# Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='This is a test. How can I assist you further?', role='assistant', function_call=None, tool_calls=None, refusal=None))

# %%
print(result.choices[0].message.content)
# Out:
# This is a test. How can I assist you further?

# %%
print(result.to_dict())
# Out:
# {'id': 'chatcmpl-AmtBOvvjX6KDgvVxQiQGTkSHoJTXX', 'choices': [{'finish_reason': 'stop', 'index': 0, 'logprobs': None, 'message': {'content': 'This is a test. How can I assist you further?', 'role': 'assistant', 'refusal': None}}], 'created': 1736215230, 'model': 'gpt-4o-2024-08-06', 'object': 'chat.completion', 'system_fingerprint': 'fp_5f20662549', 'usage': {'completion_tokens': 13, 'prompt_tokens': 12, 'total_tokens': 25, 'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0}, 'completion_tokens_details': {'reasoning_tokens': 0, 'audio_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}}}

# %%
result = chat_completion = client.chat.completions.create(
    messages=[
        {
            "role": "system",
            "content": "You are a helpful assistant."
        },
        {
            "role": "user",
            "content": "write a poem about recursion in Python"
        }
    ],
    model="gpt-4o",
)

# %%
print(result.choices[0].message.content)
# Out:
# In the realm where logic tends to dance,
# Python weaves a recursive trance.
# Functions call, upon themselves they lean,
# To solve the mysteries, unseen.
#
# A factorial's tale or the Fibonacci's climb,
# Each moment echoes a timeless rhyme.
# With every step, it nears the core,
# Yet infinite mirrors, it must explore.
#
# Defining itself with graceful ease,
# It burrows deep, like roots through trees.
# A base case anchors the spiral flow,
# Where echoes rest, and answers grow.
#
# But beware the loop that never ends,
# A careless path, which logic bends.
# Each call should lend a guiding hand,
# So all returns as once we planned.
#
# So here's to recursion, pure and bright,
# A fractal journey, a coder's light.
# In Python's code, it spins and weaves,
# A tapestry that logic believes.

# %%
def call_openai_chat(model, messages):
    result = client.chat.completions.create(
        messages=messages,
        model=model,
    )
    return result.choices[0].message.content

messages = [
    {
        "role": "user",
        "content": "Say this is a test",
    },
    {
        "role": "system",
        "content": "You are a helpful assistant.",
    },
    {
        "role": "user",
        "content": "who is the us president in 2024?"
    },
    {
        "role": "system",
        "content": "I am not sure, but I can look it up for you."
    },
    {
        "role": "user",
        "content": "who comes after him"
    }

]

# %%
call_openai_chat("gpt-4o", messages)
# Out:
# "As of my last update in October 2023, the U.S. presidential election for 2024 has not yet occurred, so I don't have information on who the President will be after 2024, nor their successor. The next President and their successor will depend on the outcomes of future elections."

# %%
import time
def call_openai_chat(model, messages):
    result = client.chat.completions.create(
        messages=messages,
        model=model,
        temperature=0.5,
        max_tokens=100,
        stream=True
    )
    for chunk in result:
        print(chunk.choices[0].delta.content, flush=True, end="") 
        time.sleep(0.2)
messages = [
    {
        "role": "user",
        "content": "Say this is a test",
    },
    {
        "role": "system",
        "content": "You are a helpful assistant.",
    },
    {
        "role": "user",
        "content": "write a poem about recursion in Python"
    },
    
]

call_openai_chat("gpt-4o", messages)
# Out:
# In the depths of Python's core,
# A concept lies we can't ignore.
# A function calls itself anew,
# A loop of logic, tried and true.
#
# Recursion is its given name,
# A self-referential, endless game.
# With base case set, it knows to end,
# Else to itself it will descend.
#
# A Fibonacci sequence to unfold,
# Or factorials, as tales are told.
# Each call a step towards the goal,
# A fractalNone

# %%
pip install nest_asyncio
# Out:
# Requirement already satisfied: nest_asyncio in /Users/junjiezhang/opt/anaconda3/lib/python3.9/site-packages (1.5.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import nest_asyncio
import asyncio

nest_asyncio.apply()

# Your existing code
with open("news_result.txt") as in_file:
    context_content = in_file.read()

system_prompt = system_prompt_template.format(
    name="Robot",
    owner="junjie",
    date="2025/01/08",
    context=context_content
)

async def chat_func():
    client = AsyncOpenAI()

    result = await client.chat.completions.create(
        model="gpt-4o",
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": "Any news about cell phones?"}
        ],
        max_tokens=256,
        temperature=0.5,
        stream=True,
    )

    async for token in result:
        print(token.choices[0].delta.content, flush=True, end="")

asyncio.run(chat_func())
# Out:
# ---------------------------------------------------------------------------
# OpenAIError                               Traceback (most recent call last)
# /var/folders/60/j13rv8sj6h7_s2bchmfjrwbm0000gn/T/ipykernel_65754/3306398328.py in <module>
#      32         print(token.choices[0].delta.content, flush=True, end="")
#      33
# ---> 34 asyncio.run(chat_func())
#
# ~/opt/anaconda3/lib/python3.9/site-packages/nest_asyncio.py in run(future, debug)
#      30         loop = asyncio.get_event_loop()
#      31         loop.set_debug(debug)
# ---> 32         return loop.run_until_complete(future)
#      33
#      34     if sys.version_info >= (3, 6, 0):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/nest_asyncio.py in run_until_complete(self, future)
#      68                 raise RuntimeError(
#      69                     'Event loop stopped before Future completed.')
# ---> 70             return f.result()
#      71
#      72     def _run_once(self):
#
# ~/opt/anaconda3/lib/python3.9/asyncio/futures.py in result(self)
#     199         self.__log_traceback = False
#     200         if self._exception is not None:
# --> 201             raise self._exception
#     202         return self._result
#     203
#
# ~/opt/anaconda3/lib/python3.9/asyncio/tasks.py in __step(***failed resolving arguments***)
#     254                 # We use the `send` method directly, because coroutines
#     255                 # don't have `__iter__` and `__next__` methods.
# --> 256                 result = coro.send(None)
#     257             else:
#     258                 result = coro.throw(exc)
#
# /var/folders/60/j13rv8sj6h7_s2bchmfjrwbm0000gn/T/ipykernel_65754/3306398328.py in chat_func()
#      16
#      17 async def chat_func():
# ---> 18     client = AsyncOpenAI()
#      19
#      20     result = await client.chat.completions.create(
#
# ~/opt/anaconda3/lib/python3.9/site-packages/openai/_client.py in __init__(self, api_key, organization, project, base_url, timeout, max_retries, default_headers, default_query, http_client, _strict_response_validation)
#     314             api_key = os.environ.get("OPENAI_API_KEY")
#     315         if api_key is None:
# --> 316             raise OpenAIError(
#     317                 "The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable"
#     318             )
#
# OpenAIError: The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable

# %%
from openai import AsyncOpenAI
import time
import asyncio

system_prompt_template = """You are {name} a virtual assistant created by {owner}. Today is {date}. You provide responses to questions that are clear, straightforward, and factually accurate, without speculation or falsehood. Given the following context, please answer each question truthfully to the best of your abilities based on the provided information. Answer each question with a brief summary followed by several bullet points. 

Example:
Summary of answer
- bullet point 1
- bullet point 2
...

<context>
{context}
</context>
"""

with open("news_result.txt") as in_file:
    context_content = in_file.read()

system_prompt = system_prompt_template.format(
    name="Robot",
    owner="junjie",
    date="2025/01/08",
    context=context_content
)

async def chat_func():
    client = AsyncOpenAI()

    result = await client.chat.completions.create(
        model="gpt-4o",
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": "Any news about cell phones?"}
        ],
        max_tokens=256,
        temperature=0.5,
        stream=True,
    )

    #print(result.choices[0].message.content)
    async for token in result:
        print(token.choices[0].delta.content, flush=True, end="")


asyncio.run(chat_func())
# Out:
# Summary of recent cell phone news:
# - Samsung Galaxy S25 images and launch poster leaked, leading to employee dismissals.
# - The Samsung Galaxy S25 is expected to have a slim design.
# - Apple is facing EU pressure to open AirDrop and AirPlay to Android and other platforms.
# - The EU might enforce interoperability for Apple's features on Android devices.
# - Apple's iPhone 17 Pro is rumored to have a new design and features for the next year.
# - New renders suggest a bold redesign for the iPhone 17 Pro Max.None

# %%
asyncio.run(chat_func())
# Out:
# Summary of recent cell phone news:
# - Samsung employees were fired after leaking images of the upcoming Samsung Galaxy S25.
# - The Samsung Galaxy S25 launch poster and hands-on photos have been leaked, suggesting a new design and features.
# - The Samsung Galaxy S25 Slim is reportedly very thin, as per recent leaks.
# - Android 16 introduces a new feature for the Google Pixel 9's fingerprint sensor, allowing use even when the screen is off.
# - The iPhone 17 Pro is expected to have seven new features next year, with rumors of a bold redesign and a "triangular" camera design.None

# %%
from openai import AsyncOpenAI
import asyncio
from datetime import datetime

client = AsyncOpenAI()

# Construct the system prompt
system_prompt_template = """You are Bobby, a virtual assistant create by Huajun. Today is {today}. You provide responses to questions that are clear, straightforward, and factually accurate, without speculation or falsehood. Given the following context, please answer each question truthfully to the best of your abilities based on the provided information. Answer each question with a brief summary followed by several bullet points. 

Example:
Summary of answer
- bullet point 1
- bullet point 2
...

<context>
{context}
</context>
"""

with open("news_result.txt") as in_file:
    context_content = in_file.read()

system_prompt = system_prompt_template.format(
    context=context_content, 
    today=datetime.today().strftime('%Y-%m-%d')
)

async def chat_func(history):

    result = await client.chat.completions.create(
        model="gpt-4o",
        messages=[{"role": "system", 
                   "content": system_prompt}] + history,
        max_tokens=256,
        temperature=0.5,
        stream=True,
    )

    buffer = ""
    async for r in result:
        next_token = r.choices[0].delta.content
        if next_token:
            print(next_token, flush=True, end="")
            buffer += next_token

    print("\n", flush=True)

    return buffer

async def continous_chat():
    history = []

    # Loop to receive user input continously
    while(True):
        user_input = input("> ")
        if user_input == "exit":
            break

        history.append({"role": "user", "content": user_input})

        # notice every time we call the chat function
        # we pass all the history to the API
        bot_response = await chat_func(history)

        history.append({"role": "assistant", "content": bot_response})

asyncio.run(continous_chat())
# Out:
# Hello! How can I assist you today?
#
# I am Bobby, a virtual assistant created by Huajun. I'm here to provide clear, straightforward, and factually accurate responses to your questions. How can I help you today?
#
# Today is January 7, 2025.
#
# Today is Tuesday, January 7, 2025.
#
# Here are some of the latest news highlights:
#
# 1. **Console Market Analysis**
#    - Industry analysts suggest that either Sony or Microsoft may need to exit the console market, with Nintendo expected to be the clear winner in the next generation of consoles.
#
# 2. **Files by Google Updates**
#    - Files by Google has introduced a new PDF viewer on Android, which includes support for Gemini's 'Ask about this PDF' feature.
#
# 3. **Oura Ring Accolades**
#    - The Oura Ring 4 has been named ZDNet's product of the year for 2024, recognized for its sleep and wellness tracking capabilities.
#
# 4. **Apple AI Controversy**
#    - Apple is facing criticism for its AI news summary feature on iPhones, which has generated inaccurate headlines, leading to calls for its removal.
#
# 5. **Chevrolet Corvette ZR1 Performance**
#    - The new Chevrolet Corvette ZR1 claims an impressive 0-60 mph time of 2.3 seconds, reportedly faster than any Lamborghini or McLaren.
#
# 6. **Winterfest Fortnite Event**
#    - Fortnite's Winterfest 2024 event is starting soon, featuring a Mariah Carey cube concert and various festive skins and presents.
#
# If you need more information on any of these
#
# There is no information provided in the context about Tesla's stock or related news today.
#
# Here are some recent news highlights related to cell phones:
#
# 1. **Samsung Galaxy S25 Leak**
#    - Images and details about the Samsung Galaxy S25 and S25 Plus have been leaked, including a launch poster and hands-on photos.
#
# 2. **iOS 18.2 Update**
#    - The latest iOS 18.2 update for iPhones includes new settings to try, and the integration of ChatGPT into iPhones has been highlighted.
#
# 3. **Android 16 Features**
#    - Android 16 introduces a new feature for the Google Pixel 9, allowing the fingerprint sensor to be used even when the screen is off.
#
# If you need more details on any of these topics, feel free to ask!
#
# Here are some recent news highlights related to Apple:
#
# 1. **AI News Summary Controversy**
#    - Apple is facing criticism for its AI news summary feature on iPhones, which has generated inaccurate headlines, leading to calls for its removal.
#
# 2. **iPhone 17 Pro Rumors**
#    - The upcoming iPhone 17 Pro is rumored to have several new features and may retain a 'triangular' camera design.
#
# 3. **EU Interoperability Requests**
#    - The EU is considering forcing Apple to open AirDrop and AirPlay to Android and other platforms, amid ongoing discussions about interoperability.
#
# If you need more information on any of these topics, feel free to ask!
